# %% [markdown]
# ## Loading files

# %% [markdown]
# Choose a path containing the .wav files to analyse :

# %%
# %matplotlib inline
from diastema import *
path = "/Users/anas/Documents/2015-07-Liban/audio_files/shawwa/hijaz/"
Violon = Melodies(path,xmin=50,xmax=800)
# Out:
# Lecture et analyse de  1  fichiers (.txt) dans le dossier : /Users/anas/Documents/2015-07-Liban/audio_files/shawwa/hijaz/

# %% [markdown]
# Plotting the Probability Density Functions of all the frequencies :

# %%
plt.figure(figsize=(16,8))
Violon.PdfsPlot(allplots="No",gpdf="Yes")

# %%
S = Violon.GlobalScale()
Inters(S)
# Out:
# [['0.00', '1/1', '+', '0.00'],
#  ['112.16', '4/3', '-', '12.78'],
#  ['-114.16', '4/3', '-', '10.77'],
#  ['-58.99', '9/8', '-', '7.84'],
#  ['172.52', '3/2', '-', '3.57'],
#  ['-190.87', '3/2', '-', '14.77']]

# %%
Violon.GP[:,0]
# Out:
# array([ 394.5434,  510.8018,  303.3408,  344.4321,  586.971 ,  254.2316])

# %%
Violon.AllTonics([0.5,1,1.5,2,2.5,3,3.5,5,7,10,15])
# Out:
# Toniques possibles de la Phrase 0  :  [390, 392, 414, 410, 402, 400, 399, 393, 393, 392, 298]
