# %%
# %matplotlib inline
from diastema import *
path = "/Users/anas/AUDIO/Chants_femmes/"
Chants = Melodies(path)
# Out:
# Lecture et analyse de  309  fichiers (.txt) dans le dossier : /Users/anas/AUDIO/Chants_femmes/

# %%
Y = Chants.PdfCorr(out="pdist",metric='euclidean')
Z = linkage(Y)
plt.figure(figsize=(16,8))
D = dendrogram(Z,labels=Y.dtype.names)

# %%
type(Y)
# Out:
# numpy.ndarray

# %%
Y
# Out:
# array([ 0.0132,  0.0832,  0.0472, ...,  0.0349,  0.035 ,  0.0456])

# %%
Chants.freqref
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-21-a711b28d5d60> in <module>()
# ----> 1 Chants.freqref
#
# AttributeError: 'Melodies' object has no attribute 'freqref'

# %%
Chants.file_path
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-22-d2cabe608cfe> in <module>()
# ----> 1 Chants.file_path
#
# AttributeError: 'Melodies' object has no attribute 'file_path'
