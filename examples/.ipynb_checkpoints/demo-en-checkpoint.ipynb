# %%
# %matplotlib inline
from diastema import *
path = "/Users/anas/Music/Chants_femmes/wav/Bembla/"
Bem = Melodies(path)
# Out:
# Lecture et analyse de  59  fichiers (.txt) dans le dossier : /Users/anas/Music/Chants_femmes/wav/Bembla/

# %%
Bem.Simatrix()

# %%
plt.plot(Bem.PdfCorr[1])

# %%
numpy.set_printoptions(precision=5)
b = gaussian_kde(Bem.PdfCorr[1])

# %%
x = numpy.arange(0,1,0.001)
plt.plot(x,b(x))

# %%
corr = Bem.PdfCorr[1]

# %%
corr
# Out:
# array([ 0.98927,  1.     , -0.05363, -0.16459,  0.5734 ,  0.26053,
#         0.26944,  0.34028,  0.80757,  0.50194,  0.67244,  0.47447,
#         0.29882,  0.14648,  0.64267,  0.06112,  0.93822,  0.26411,
#         0.28484,  0.83229,  0.49825,  0.35489,  0.42406, -0.0983 ,
#         0.34199, -0.10282,  0.34033,  0.92265,  0.23127,  0.11812,
#         0.67354,  0.79366,  0.85087,  0.79763,  0.77119,  0.79839,
#         0.71166,  0.86939,  0.6622 ,  0.7007 ,  0.89681, -0.2208 ,
#        -0.25333, -0.12704, -0.23336, -0.05593, -0.23235, -0.18677,
#        -0.18128, -0.20417,  0.08938, -0.04142,  0.3003 , -0.00103,
#        -0.18363,  0.37436,  0.21898, -0.08777, -0.16084])

# %%
ndx = [e for e in numpy.searchsorted(corr,[0.34879]) if e<len(corr) ]

# %%
ndx
# Out:
# []

# %%
corr[corr>=0.7]t
# Out:
#   File "<ipython-input-12-3b86998fea10>", line 1
#     corr[corr>=0.7]t
#                    ^
# SyntaxError: invalid syntax
