# %% [markdown]
# ## Loading files

# %% [markdown]
# Choose a path containing the .wav files to analyse :

# %%
# %matplotlib inline
from diastema import *
path = "/Users/anas/AUDIO/Violon_Sikah/"
Violon = Melodies(path,xmin=230,xmax=600)
# Out:
# Lecture et analyse de  5  fichiers (.txt) dans le dossier : /Users/anas/AUDIO/Violon_Sikah/

# %% [markdown]
# Plotting the Probability Density Functions of all the frequencies :

# %%
plt.figure(figsize=(16,8))
Violon.PdfsPlot(allplots="No",gpdf="Yes")

# %%
P = Violon.GlobalPeaks()[:,0]
P
# Out:
# array([ 319.2412,  388.4282,  346.3144,  415.5014,  485.6911,  294.1734,
#         260.0813,  517.7778,  448.5908,  579.9458])

# %%
log10(319.2412/388.4282)*1000
# Out:
# -85.19181767112303

# %%
epi(list="Yes")
# Out:
# 2/1*4/3  ::  425.969 s.
# 4/3  ::  124.939 s.
# 12/11  ::  37.7886 s.
# 1/1  ::  0.0 s.
# 6/5  ::  79.1812 s.
# 3/2*6/5  ::  255.273 s.
# 9/8*12/11  ::  88.9411 s.
# 3/2*5/4  ::  273.001 s.
# 2/1*12/11  ::  338.819 s.
# 3/2*9/8  ::  227.244 s.
# 2/1*9/8  ::  352.183 s.
# 2/1*6/5  ::  380.211 s.
# 3/2  ::  176.091 s.
# 5/4  ::  96.91 s.
# 3/2*10/9  ::  221.849 s.
# 2/1  ::  301.03 s.
# 10/9  ::  45.7575 s.
# 2/1*10/9  ::  346.787 s.
# 9/8  ::  51.1525 s.
# 2/1*5/4  ::  397.94 s.
# {'1/1': 1.0,
#  '10/9': 1.1111111111111112,
#  '12/11': 1.0909090909090908,
#  '2/1': 2.0,
#  '2/1*10/9': 2.2222222222222223,
#  '2/1*12/11': 2.1818181818181817,
#  '2/1*4/3': 2.6666666666666665,
#  '2/1*5/4': 2.5,
#  '2/1*6/5': 2.4,
#  '2/1*9/8': 2.25,
#  '3/2': 1.5,
#  '3/2*10/9': 1.6666666666666667,
#  '3/2*5/4': 1.875,
#  '3/2*6/5': 1.8,
#  '3/2*9/8': 1.6875,
#  '4/3': 1.3333333333333333,
#  '5/4': 1.25,
#  '6/5': 1.2,
#  '9/8': 1.125,
#  '9/8*12/11': 1.2272727272727273}

# %%
S = Violon.GlobalScale()
Inters(S)
# Out:
# [['33.75', '12/11', '-', '4.03'],
#  ['118.95', '4/3', '-', '5.99'],
#  ['69.11', '6/5', '-', '10.08'],
#  ['148.21', '4/3', '+', '23.27'],
#  ['216.00', '3/2*10/9', '-', '5.85'],
#  ['-1.76', '1/1', '-', '1.76'],
#  ['-55.26', '9/8', '-', '4.10'],
#  ['243.78', '3/2*6/5', '-', '11.49'],
#  ['181.49', '3/2', '+', '5.39'],
#  ['293.02', '2/1', '-', '8.01']]

# %% [markdown]
# Plotting the self-similarity matrix :

# %%
Violon.Simatrix()
