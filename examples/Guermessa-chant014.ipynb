# %% [markdown]
# # Guermessa 014

# %%
# %matplotlib inline
from diastema import *
path = "/Users/anas/AUDIO/Guermessa014/"
Guerm = Melodies(path,xmin=230,xmax=600)
# Out:
# Lecture et analyse de  8  fichiers (.txt) dans le dossier : /Users/anas/AUDIO/Guermessa014/

# %%
plt.figure(figsize=(16,8))
Guerm.PdfsPlot(allplots="Yes",gpdf="No")

# %%
plt.figure(figsize=(16,8))
Guerm.PdfsPlot(allplots="No",gpdf="Yes")

# %%
S = Guerm.GlobalScale()
Inters(S)
# Out:
# Scale following the order of importance (peaks)
# [['0.00', '1/1', '+', '0.00'],
#  ['113.25', '4/3', '-', '11.69'],
#  ['158.01', '3/2', '-', '18.08'],
#  ['67.85', '7/6', '+', '0.90'],
#  ['28.75', '16/15', '+', '0.72']]

# %%
Guerm.GetTheTonic()
# Out:
# 249.05149051490514

# %%
Guerm.GlobalPeaks()[:,0]
# Out:
# array([ 249.0515,  323.252 ,  358.3469,  291.1653,  266.0976])

# %%
log10(249/323.)*1000
# Out:
# -113.00317523536654

# %%
Y = Guerm.PdfCorr(out="pdist",metric='correlation')
from scipy.cluster.hierarchy import linkage,dendrogram
Z = linkage(Y)
D = dendrogram(Z)
