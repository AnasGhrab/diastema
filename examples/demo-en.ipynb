# %%
# %matplotlib inline
from diastema import *
path = "/Users/anas/AUDIO/Chants_femmes/"
Chants = Melodies(path)
# Out:
# Analyse de  0  fichiers Audio (.wav) dans le dossier :

# %%
Chants.Simatrix()
