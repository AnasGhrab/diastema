# %%
# %matplotlib inline
from diastema import *
path = "/Users/anas/Music/Chants_femmes/wav/Bembla/"
Bem = Melodies(path)
# Out:
# Lecture et analyse de  59  fichiers (.txt) dans le dossier : /Users/anas/Music/Chants_femmes/wav/Bembla/

# %%
Bem.Simatrix()

# %%
plt.plot(Bem.PdfCorr[1])

# %%
numpy.set_printoptions(precision=5)
b = gaussian_kde(Bem.PdfCorr[1])

# %%
x = numpy.arange(0,1,0.001)
plt.plot(x,b(x))

# %%
corr = Bem.PdfCorr[1]

# %%
corr
# Out:
# array([ 1.     ,  0.98505,  0.17832,  0.80307,  0.58358,  0.09176,
#         0.18679,  0.34579,  0.95945,  0.04816,  0.20029, -0.08473,
#         0.58943,  0.15035,  0.91712, -0.07982,  0.95456, -0.01593,
#        -0.02115,  0.22   ,  0.0381 ,  0.16562,  0.70433,  0.13573,
#         0.76375,  0.60316,  0.1824 ,  0.84761,  0.13059, -0.25454,
#         0.77546,  0.7365 ,  0.34879, -0.06325,  0.79181,  0.40335,
#         0.82509,  0.17533,  0.92079,  0.177  , -0.09099,  0.29062,
#         0.22839,  0.49529,  0.28556,  0.89797,  0.58545,  0.69836,
#         0.67993,  0.36253,  0.21128,  0.15876,  0.15804,  0.27408,
#         0.74018,  0.80671,  0.14526,  0.19061,  0.49131])

# %%
ndx = [e for e in numpy.searchsorted(corr,numpy.arange(0.6,0.8,0.00001)) if e<len(corr) ]

# %%
numpy.arange(0.6,0.8,0.00001)
# Out:
# array([ 0.6    ,  0.60001,  0.60002, ...,  0.79998,  0.79999,  0.8    ])

# %%
ndx = [e for e in numpy.searchsorted(corr,[0.34879]) if e<len(corr) ]

# %%
ndx
# Out:
# [58]

# %%
corr[corr>=0.7]t
# Out:
# array([ 1.     ,  0.98505,  0.80307,  0.95945,  0.91712,  0.95456,
#         0.70433,  0.76375,  0.84761,  0.77546,  0.7365 ,  0.79181,
#         0.82509,  0.92079,  0.89797,  0.74018,  0.80671])
