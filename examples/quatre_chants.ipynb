# %%
# %matplotlib inline
from diastema import *
path = "/Users/anas/AUDIO/quatre_chants/"
Kchants = Melodies(path,xmin=250,xmax=400,transpose="Yes")
# Out:
# Lecture et analyse de  4  fichiers (.txt) dans le dossier : /Users/anas/AUDIO/quatre_chants/

# %%
plt.figure(figsize=(16,8))
Kchants.PdfsPlot(allplots="Yes",gpdf="No")

# %%
Y = Kchants.PdfCorr(out="pdist",metric='correlation')
Z = linkage(Y)
D = dendrogram(Z)

# %%
Y = Kchants.PdfCorr(out="pdist",metric='cosine')
Z = linkage(Y)
D = dendrogram(Z)

# %%
squareform(Y)
# Out:
# array([[ 0.    ,  0.0982,  0.021 ,  0.1252],
#        [ 0.0982,  0.    ,  0.1141,  0.1075],
#        [ 0.021 ,  0.1141,  0.    ,  0.1348],
#        [ 0.1252,  0.1075,  0.1348,  0.    ]])
